# %%
import pandas as pd

# %%
df = pd.read_csv("Data/daily_features.csv")

# %%
print(df.head(20))
# Out:
#     price_id  ticker_id  trade_date  return_1d  return_2d  return_3d  \
# 0          1          1  1999-11-18        NaN        NaN        NaN
# 1          2          1  1999-11-19  -0.082373        NaN        NaN
# 2          3          1  1999-11-22   0.089767   0.000000        NaN
# 3          4          1  1999-11-23  -0.090846  -0.009233  -0.090846
# 4          5          1  1999-11-24   0.026380  -0.066862   0.016904
# 5          6          1  1999-11-26   0.003288   0.029755  -0.063794
# 6          7          1  1999-11-29   0.022450   0.025811   0.052873
# 7          8          1  1999-11-30   0.001754   0.024243   0.027611
# 8          9          1  1999-12-01   0.017737   0.019523   0.042411
# 9         10          1  1999-12-02   0.027540   0.045766   0.047601
# 10        11          1  1999-12-03   0.008484   0.036258   0.054639
# 11        12          1  1999-12-06   0.028130   0.036853   0.065408
# 12        13          1  1999-12-07  -0.010935   0.016888   0.025515
# ...
